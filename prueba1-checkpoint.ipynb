# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
if __name__ == '_prueba1_':
    url = 'https://www.google.com/'
    response = requests.get(url)
if response.status_code == 200:
    print(response.content)
# Out:
# b'\n<!doctype html>\n<html prefix="og: http://ogp.me/ns#" lang="es-es" dir="ltr">\n    <head>\n        <meta charset="utf-8">\n        <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\n        <link rel="canonical" href="https://www.ucundinamarca.edu.co/">\n        <base href="https://www.ucundinamarca.edu.co/" />\n\t<meta http-equiv="content-type" content="text/html; charset=utf-8" />\n\t<meta name="keywords" content="Universidad, Educaci\xc3\xb3n, Cundinamarca" />\n\t<meta name="description" content="Universidad de educaci\xc3\xb3n superior a distancia, virtual, presencial" />\n\t<meta name="generator" content="HELIX_ULTIMATE_GENERATOR_TEXT" />\n\t<title>UCundinamarca</title>\n\t<link href="/images/iconos/favicon2019.png" rel="shortcut icon" type="image/vnd.microsoft.icon" />\n\t<link href="https://www.ucundinamarca.edu.co/index.php/component/search/?id=391&amp;Itemid=1828&amp;format=opensearch" rel="search" title="Buscar UCundinamarca" type="a
# ...
